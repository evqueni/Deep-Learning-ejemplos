# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
df = pd.read_csv("vgsales.csv")
Y=df["Global_Sales"]
X=
LRegres = LinearRegression()
LRegres.fit(X,Y)
print("Intercept:",regress.intercept_)
print("Coeficiente:",regress.coef_)
print("R-Cuadrado:",regress.score(X,Y))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-43f437b73837> in <module>
#       3 df = pd.read_csv("vgsales.csv")
#       4 Y=df["Global_Sales"]
# ----> 5 X=df.data()
#       6 LRegres = LinearRegression()
#       7 LRegres.fit(X,Y)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'data'

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import pearsonr 
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
#**************************************************
ProduccionTrigo =[30,28,32,25,25,25,22,24,35,40]
PrecioHarina =[25,30,27,40,42,40,50,45,30,25]
d={'ProduccionTrigo':ProduccionTrigo,'PrecioHarina':PrecioHarina}
#**************************************************
regresionDF = pd.DataFrame(d)
X=regresionDF['ProduccionTrigo'].values.reshape(-1,1)
Y=regresionDF['PrecioHarina'].values
regress=Lasso(alpha=0.01)
regress.fit(X,Y)
print("Intercept:",regress.intercept_)
print("Coeficiente:",regress.coef_)
print("R-Cuadrado:",regress.score(X,Y))
plt.plot(X,(74.115-1.3537*X),color='red')
plt.scatter(X,Y)
plt.xlabel("Producción de Trigo(Toneladas)")
plt.ylabel("Precio de la harina (euro)")
plt.title("Producción de trigo vs precio de la harina")
plt.show()
# Out:
# Intercept: 74.10520110957003
# Coeficiente: [-1.35332871]
# R-Cuadrado: 0.7176464710805877

# %%
plt.scatter(Y,(74.115-1.3537*X))
plt.xlabel("Valores Reales)")
plt.ylabel("Valores Predichos")
plt.title("ScatterPlot de Reales vs Predichos")
# Out:
# Text(0.5, 1.0, 'ScatterPlot de Reales vs Predichos')
